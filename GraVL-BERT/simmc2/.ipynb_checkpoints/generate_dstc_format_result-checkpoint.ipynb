# %%
import json
import numpy as np

# %%
pred_path = '/Users/danfengg/Documents/VL-BERT/simmc2/results/devtest/devtest_34.json'
pred = json.load(open(pred_path, 'r'))[0]
ori_path = '/Users/danfengg/Documents/labels/simmc2_dials_dstc10_devtest.json'
ori = json.load(open(ori_path, 'r'))['dialogue_data']
label_path = '/Users/danfengg/Documents/proc_labels/devtest_preprocessed_v2.json'
label = json.load(open(label_path, 'r'))['data']
save_path = '/Users/danfengg/Documents/VL-BERT/simmc2/results/devtest/results_dstc_34.json'

# %%
cur_dlg_index = None
mentioned_objs_dlevel = []
for ind, logits in enumerate(pred['answer_logits']):
    objs = label[ind]['objects']
    turn_index = label[ind]['turn_index']
    dlg_index = label[ind]['dialogue_index']
    if cur_dlg_index == None:
        cur_dlg_index = dlg_index
    if cur_dlg_index != dlg_index:
        mentioned_objs_dlevel = []
        cur_dlg_index = dlg_index
    ref_objs = [objs[i] for i in range(len(objs)) if logits[i] > 0.5]
    ref_objs = [int(i.replace('[OBJ', '').replace(']', '')) for i in ref_objs]
    mentioned_objs_dlevel += ref_objs
    ori[cur_dlg_index]['mentioned_object_ids'] = mentioned_objs_dlevel
    ori[cur_dlg_index]['dialogue'][turn_index]['transcript_annotated']['act_attributes']['objects'] = ref_objs

json.dump({"dialogue_data": ori}, open(save_path, 'w'))

# %%
# Out:
# 3445

# %%
label[0]
# Out:
# {'annot_id': 0,
#  'objects': ['[OBJ0]',
#   '[OBJ1]',
#   '[OBJ2]',
#   '[OBJ39]',
#   '[OBJ40]',
#   '[OBJ41]',
#   '[OBJ10]',
#   '[OBJ12]',
#   '[OBJ13]',
#   '[OBJ42]',
#   '[OBJ11]',
#   '[OBJ43]',
#   '[OBJ44]',
#   '[OBJ30]',
#   '[OBJ35]',
#   '[OBJ25]',
#   '[OBJ19]',
#   '[OBJ18]',
#   '[OBJ20]',
#   '[OBJ24]',
#   '[OBJ21]',
#   '[OBJ22]',
#   '[OBJ28]',
#   '[OBJ31]',
#   '[OBJ15]',
#   '[OBJ16]',
#   '[OBJ17]',
#   '[OBJ26]',
#   '[OBJ27]',
#   '[OBJ14]',
#   '[OBJ23]',
#   '[OBJ34]',
#   '[OBJ36]',
#   '[OBJ33]',
#   '[OBJ45]',
#   '[OBJ29]',
#   '[OBJ46]',
#   '[OBJ38]',
#   '[OBJ47]',
#   '[OBJ48]',
#   '[OBJ49]',
#   '[OBJ50]',
#   '[OBJ51]'],
#  'img_fn': 'm_cloth_store_1416238_woman_3_8',
#  'boxes': [[387, 139, 462, 361],
#   [454, 192, 509, 346],
#   [506, 216, 549, 349],
#   [1239, 217, 1303, 373],
#   [1299, 222, 1361, 353],
#   [1207, 240, 1244, 366],
#   [69, 166, 223, 614],
#   [470, 367, 519, 523],
#   [513, 350, 558, 515],
#   [1206, 368, 1240, 531],
#   [398, 352, 470, 576],
#   [1247, 373, 1290, 540],
#   [1293, 372, 1349, 562],
#   [923, 487, 936, 524],
#   [978, 488, 1012, 516],
#   [947, 493, 992, 532],
#   [566, 570, 630, 583],
#   [545, 580, 616, 598],
#   [576, 555, 645, 573],
#   [663, 551, 720, 574],
#   [652, 561, 713, 587],
#   [641, 579, 706, 595],
#   [636, 590, 705, 606],
#   [1017, 450, 1040, 721],
#   [482, 627, 576, 654],
#   [516, 604, 588, 628],
#   [524, 593, 602, 614],
#   [607, 627, 689, 650],
#   [613, 604, 700, 631],
#   [887, 485, 909, 748],
#   [856, 510, 876, 738],
#   [915, 490, 1022, 770],
#   [1056, 488, 1082, 717],
#   [942, 526, 1009, 782],
#   [1646, 597, 1872, 966],
#   [147, 681, 276, 1003],
#   [1380, 784, 1415, 873],
#   [1077, 756, 1299, 1003],
#   [1262, 770, 1342, 987],
#   [1032, 845, 1238, 986],
#   [986, 883, 1257, 1003],
#   [1302, 866, 1631, 1002],
#   [1461, 939, 1550, 1003]],
#  'segms': [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None],
#  'question': "[USER] Do you have any plain jeans? [SYS] What do you think of the grey pair on the left? [USER] Sorry, I misspoke. Can you show me dresses instead? [SYS] There's a maroon one on the wall on the right, and a brown one and a grey one on the rack. [USER] Does the grey have good reviews? [SYS] Which one do you mean? [QRY] The grey one on the hanging rack.",
#  'obj_meta': ['Customer review score 3.6. brand The Vegan Baker. Price 29.99. size L. ',
#   'Customer review score 4.5. brand Art Den. Price 54.99. size XL. ',
#   'Customer review score 3.5. brand Cats Are Great. Price 19.99. size XXL. ',
#   'Customer review score 2.6. brand 212 Local. Price 44.99. size XL. ',
#   'Customer review score 3.6. brand Pedals & Gears. Price 19.99. size S. ',
#   'Customer review score 3.1. brand Downtown Consignment. Price 209.99. size XL. ',
#   'Customer review score 4.8. brand Cats Are Great. Price 139.99. size L. ',
#   'Customer review score 4.4. brand Cats Are Great. Price 4.99. size XS. ',
#   'Customer review score 4.9. brand Downtown Stylists. Price 59.99. size XL. ',
#   'Customer review score 3.2. brand Nature Photographers. Price 184.99. size L. ',
#   'Customer review score 2.9. brand StyleNow Feed. Price 54.99. size S. ',
#   'Customer review score 4.2. brand Pedals & Gears. Price 239.99. size M. ',
#   'Customer review score 3.6. brand Uptown Gallery. Price 224.99. size XL. ',
#   'Customer review score 4.2. brand Downtown Stylists. Price 74.99. size XL. ',
#   'Customer review score 4.2. brand Pedals & Gears. Price 239.99. size M. ',
#   'Customer review score 4.3. brand Yogi Fit. Price 124.99. size XXL. ',
#   'Customer review score 4.2. brand Brain Puzzles. Price 74.99. size XL. ',
#   'Customer review score 3.6. brand River Chateau. Price 164.99. size XS. ',
#   'Customer review score 3.4. brand Garden Retail. Price 124.99. size L. ',
#   'Customer review score 4.9. brand Garden Retail. Price 84.99. size XXL. ',
#   'Customer review score 4.4. brand Brain Puzzles. Price 39.99. size XS. ',
#   'Customer review score 4.4. brand Art Den. Price 74.99. size S. ',
#   'Customer review score 3.3. brand Glam Nails. Price 64.99. size M. ',
#   'Customer review score 4.3. brand Fancy Nails. Price 229.99. size M. ',
#   'Customer review score 3.1. brand Pedals & Gears. Price 204.99. size S. ',
#   'Customer review score 3.5. brand The Vegan Baker. Price 69.99. size S. ',
#   'Customer review score 4.4. brand Uptown Gallery. Price 29.99. size XL. ',
#   'Customer review score 4.1. brand Art Den. Price 89.99. size XL. ',
#   'Customer review score 4.5. brand Downtown Stylists. Price 169.99. size M. ',
#   'Customer review score 4.7. brand Global Voyager. Price 24.99. size M. ',
#   'Customer review score 4.5. brand 212 Local. Price 174.99. size L. ',
#   'Customer review score 4.3. brand Fancy Nails. Price 229.99. size M. ',
#   'Customer review score 4.3. brand Yogi Fit. Price 124.99. size XXL. ',
#   'Customer review score 4.1. brand Home Store. Price 149.99. size XS. ',
#   'Customer review score 3.5. brand The Vegan Baker. Price 244.99. size XS. ',
#   'Customer review score 4.3. brand Cats Are Great. Price 164.99. size L. ',
#   'Customer review score 4.1. brand Downtown Stylists. Price 59.99. size XL. ',
#   'Customer review score 4.5. brand North Lodge. Price 109.99. size L. ',
#   'Customer review score 4.0. brand 212 Local. Price 144.99. size XXL. ',
#   'Customer review score 3.1. brand New Fashion. Price 19.99. size XS. ',
#   'Customer review score 3.9. brand Nature Photographers. Price 69.99. size L. ',
#   'Customer review score 4.0. brand 212 Local. Price 144.99. size XXL. ',
#   'Customer review score 4.8. brand HairDo. Price 54.99. size M. '],
#  'answer_choices': ['[OBJ36]'],
#  'mentioned_turns': [0, 1, 0],
#  'mentioned_lbl': {'[OBJ29]': 0, '[OBJ42]': 1, '[OBJ14]': 1, '[OBJ36]': 1},
#  '3d_pos': [[2.8300000381469728, 1.8799999523162843, 1.0200001049041747],
#   [3.500000114440918, 1.889999942779541, 1.0200001049041747],
#   [4.179999942779541, 1.889999942779541, 1.0200001049041747],
#   [9.62, -4.659999771118164, -3.629999990463257],
#   [3.62, -2.6400000286102294, 0.9999998855590819],
#   [4.9099999618530275, -2.6400000286102294, 0.9999998855590819],
#   [-1.2100000429153441, 2.4099999237060548, 0.03999996662139882],
#   [3.4699999046325685, 1.889999942779541, 0.1599999713897704],
#   [4.1599999618530275, 1.889999942779541, -0.24999999523162852],
#   [4.850000019073486, -2.6799999904632568, -0.029999966621399032],
#   [2.7700000953674317, 1.889999942779541, 0.16999996185302724],
#   [4.2199999046325685, -2.67, -0.00999998569488536],
#   [3.6100000095367433, -2.67, -0.06000005722045909],
#   [2.7199999046325685, -0.300000002682209, -0.3400000286102296],
#   [2.949999923706055, -0.5499999952316283, -0.5500000071525575],
#   [2.4599999141693116, -0.31999999850988387, -0.3200000476837159],
#   [3.9099999618530275, 1.5500000286102296, -0.5900000286102296],
#   [3.6100000095367433, 1.5600000190734864, -0.5699999880790712],
#   [4.210000152587891, 1.5400000381469727, -0.5699999880790712],
#   [4.210000152587891, 1.0700000095367432, -0.6100000095367433],
#   [3.9099999618530275, 1.0700000095367432, -0.6100000095367433],
#   [3.62, 1.08, -0.5900000286102296],
#   [3.310000057220459, 1.0500000286102296, -0.5599999976158143],
#   [2.5200000953674317, -0.639999998807907, -0.3899999809265138],
#   [2.7199999046325685, 1.5500000286102296, -0.5599999976158143],
#   [3.0200000953674317, 1.5600000190734864, -0.6100000095367433],
#   [3.320000047683716, 1.5600000190734864, -0.5699999880790712],
#   [2.7199999046325685, 1.0500000286102296, -0.5900000286102296],
#   [3.010000104904175, 1.0600000190734864, -0.5699999880790712],
#   [2.7299998950958253, -0.07000000596046446, -0.5400000166893006],
#   [2.739999885559082, 0.08999999046325685, -0.6000000190734864],
#   [2.250000114440918, -0.31999999850988387, -0.5199999761581422],
#   [2.5800000381469728, -0.7699999940395355, -0.3400000286102296],
#   [2.0900000286102296, -0.31999999850988387, -0.5699999880790712],
#   [0.9999999952316284, -2.600000066757202, -1.139999995827675],
#   [0.9999999952316284, 1.83, -1.099999989271164],
#   [-0.5199999856948853, 3.900000171661377, -4.520000095367432],
#   [-0.369999994635582, 0.8200000095367432, -3.4599999141693116],
#   [0.0899999988079071, -0.5499999952316283, -0.35000001907348643],
#   [0.05000000715255737, -0.2399999928474426, -0.5699999880790712],
#   [-0.03999999642372132, -0.16999999999999998, -0.5699999880790712],
#   [-0.11000000044703484, -0.6599999946355819, -0.35000001907348643],
#   [-0.23000000149011612, -0.639999998807907, -0.5699999880790712]],
#  'prev_ref': 0,
#  'turn_index': 3,
#  'dialogue_index': 0}
